# %%
import cv2
from tensorflow.keras.preprocessing.image import img_to_array
import numpy as np
from tensorflow.keras.models import load_model

# %%
def detect_face(img):
    coord = haar.detectMultiScale(img)
    
    return coord

# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model
from keras.preprocessing.image import img_to_array
import pandas as pd

# Function to reassemble the model parts
def reassemble_model(parts, output_file):
    with open(output_file, 'wb') as f_out:
        for part in parts:
            with open(part, 'rb') as f_in:
                f_out.write(f_in.read())
    print(f"Model reassembled to {output_file}")

# List of the parts
parts = ['emotion_recognition_model_part_aa', 'emotion_recognition_model_part_ab', 'emotion_recognition_model_part_ac']

# Reassemble the model
reassemble_model(parts, 'emotion_recognition_model_reassembled.h5')

# Load the reassembled model
model_tuned = load_model("emotion_recognition_model_reassembled.h5")
# Load the model and face detector
haar = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
model_tuned = load_model("emotion_recognition_model.h5")

# Load movie data
try:
    movie_data = pd.read_csv('movies.csv')
    print("Movie data loaded successfully.")
except Exception as e:
    print(f"Error loading movie data: {e}")
    movie_data = None  # Handle missing movie data gracefully

# Emotion classes
classes = ['Angry', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']

def get_random_movie(emotion):
    if movie_data is None:
        return "Movie data unavailable."
    filtered_movies = movie_data[movie_data['Emotion'] == emotion]
    if not filtered_movies.empty:
        random_movie = filtered_movies.sample(n=1)
        return f"Recommended Movie: {random_movie['Movie Title'].values[0]} ({random_movie['Genre'].values[0]})"
    else:
        return "No recommendations available for this emotion."

def detect_face(img):
    coord = haar.detectMultiScale(img)
    print("Faces detected:", coord)
    return coord

webcam = cv2.VideoCapture(0)

if not webcam.isOpened():
    print("Error: Could not access the webcam.")
else:
    print("Webcam opened successfully.")

while webcam.isOpened():
    status, frame = webcam.read()
    if not status:
        print("Error: Failed to capture frame.")
        break

    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    coords = detect_face(gray_frame)

    for x, y, w, h in coords:
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 3)

        face_crop = gray_frame[y:y + h, x:x + w]
        if face_crop.shape[0] < 10 or face_crop.shape[1] < 10:
            continue

        face_crop = cv2.resize(face_crop, (48, 48))
        face_crop = face_crop.astype("float") / 255.0
        face_crop = np.expand_dims(face_crop, axis=-1)
        face_crop = np.expand_dims(face_crop, axis=0)

        conf = model_tuned.predict(face_crop)[0]
        idx = np.argmax(conf)
        label = classes[idx]

        cv2.putText(frame, label, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 255), 2)
        print(f"Emotion Detected: {label}")
        print(get_random_movie(label))

    cv2.imshow("Emotion Detection", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

webcam.release()
cv2.destroyAllWindows()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Movie data loaded successfully.
# Webcam opened successfully.
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: [[414 117 818 818]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# Emotion Detected: Surprise
# Recommended Movie: Shutter Island (Thriller/Mystery)
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: [[206  72 987 987]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Emotion Detected: Sad
# Recommended Movie: Up in the Air (Drama)
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: [[1106  948   45   45]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Emotion Detected: Surprise
# Recommended Movie: The Prestige (Drama/Mystery)
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: [[ 67   0 818 818]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Emotion Detected: Sad
# Recommended Movie: The Fault in Our Stars (Romance/Drama)
# Faces detected: [[162 161  63  63]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Emotion Detected: Surprise
# Recommended Movie: Shrek (Animation/Adventure)
# Faces detected: ()
# Faces detected: ()
# Faces detected: [[ 17 549  64  64]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Emotion Detected: Neutral
# Recommended Movie: Eternal Sunshine of the Spotless Mind (Drama/Romance)
# Faces detected: [[ 146  941  132  132]
#  [ 180  892   69   69]
#  [  62  988   44   44]
#  [  61  998   57   57]
#  [1115 1005   63   63]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Emotion Detected: Surprise
# Recommended Movie
]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Emotion Detected: Surprise
# Recommended Movie: Jumanji (Adventure/Comedy)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Emotion Detected: Surprise
# Recommended Movie: Atonement (Drama/Romance)
# Faces detected: [[331   8 106 106]
#  [337 102 178 178]
#  [315 363  57  57]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Emotion Detected: Surprise
# Recommended Movie: The Prestige (Drama/Mystery)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Emotion Detected: Surprise
# Recommended Movie: The Machinist (Drama/Thriller)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Emotion Detected: Surprise
# Recommended Movie: The Truman Show (Drama/Comedy)
# Faces detected: [[340 102 178 178]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Emotion Detected: Surprise
# Recommended Movie: Primal Fear (Thriller/Drama)
# Faces detected: [[340  14 105 105]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Emotion Detected: Surprise
# Recommended Movie: The Departed (Crime/Thriller)
# Faces detected: [[340  92 192 192]
#  [328 364  58  58]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Emotion Detected: Surprise
# Recommended Movie: The Machinist (Drama/Thriller)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Emotion Detected: Surprise
# Recommended Movie: Atonement (Drama/Romance)
# Faces detected: [[342  13 118 118]
#  [349 105 181 181]
#  [331 369  56  56]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Emotion Detected: Surprise
# Recommended Movie: The Village (Drama/Mystery)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Emotion Detected: Surprise
# Recommended Movie: Prisoners (Crime/Thriller)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Emotion Detected: Surprise
# Recommended Movie: The Game (Thriller/Drama)
# Faces detected: [[351  21  97  97]
#  [354 111 174 174]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Emotion Detected: Surprise
# Recommended Movie: Shutter Island (Thriller/Mystery)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Emotion Detected: Surprise
# Recommended Movie: The Prestige (Drama/Mystery)
# Faces detected: [[376  20 167 167]
#  [330 206 854 854]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Emotion Detected: Surprise
# Recommended Movie: The Prestige (Drama/Mystery)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Emotion Detected: Sad
# Recommended Movie: Lion (Drama)
# Faces detected: [[260 173 864 864]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Emotion Detected: Sad
# Recommended Movie: The Fault in Our Stars (Romance/Drama)
# Faces detected: [[212 127 895 895]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Emotion Detected: Sad
# Recommended Movie: The Pianist (Drama/Music)
# Faces detected: [[ 227   72  900  900]
#  [1470  983   54   54]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Emotion Detected: Sad
# Recommended Movie: Million Dollar Baby (Drama)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Emotion Detected: Surprise
# Recommended Movie: The Departed (Crime/Thriller)
# Faces detected: [[ 225   99  879  879]
#  [1466  989   54   54]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Emotion Detected: Sad
# Recommended Movie: The Perks of Being a Wallflower (Drama/Romance)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Emotion Detected: Surprise
# Recommended Movie: The Departed (Crime/Thriller)
# Faces detected: [[ 203  100  898  898]
#  [1364 1020   25   25]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Emotion Detected: Sad
# Recommended Movie: Titanic (Drama/Romance)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Emotion Detected: Surprise
# Recommended Movie: The Sixth Sense (Drama/Mystery)
# Faces detected: [[ 197  103  900  900]
#  [1452 1011   54   54]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Emotion Detected: Sad
# Recommended Movie: Forest Gump (Drama)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Emotion Detected: Surprise
# Recommended Movie: Atonement (Drama/Romance)
# Faces detected: [[ 209  114  888  888]
#  [1453 1018   57   57]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Emotion Detected: Sad
# Recommended Movie: Forest Gump (Drama)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Emotion Detected: Surprise
# Recommended Movie: The Illusionist (Drama/Mystery)
# Faces detected: [[ 203  113  903  903]
#  [1406 1028   41   41]
#  [1454 1019   58   58]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Emotion Detected: Sad
# Recommended Movie: A Walk to Remember (Drama/Romance)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Emotion Detected: Surprise
# Recommended Movie: Memento (Drama/Mystery)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Emotion Detected: Surprise
# Recommended Movie: The Sixth Sense (Drama/Mystery)
# Faces detected: [[ 211  130  889  889]
#  [1453 1025   54   54]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Emotion Detected: Sad
# Recommended Movie: My Sister's Keeper (Drama)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Emotion Detected: Surprise
# Recommended Movie: The Illusionist (Drama/Mystery)
# Faces detected: [[ 223  137  878  878]
#  [1406 1036   41   41]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Emotion Detected: Sad
# Recommended Movie: Requiem for a Dream (Drama)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Emotion Detected: Surprise
# Recommended Movie: The Departed (Crime/Thriller)
# Faces detected: [[229 134 884 884]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Emotion Detected: Sad
# Recommended Movie: Bridge to Terabithia (Adventure/Drama)
# Faces detected: [[228 136 884 884]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Emotion Detected: Sad
# Recommended Movie: The Shack (Drama)
# Faces detected: [[224 133 880 880]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Emotion Detected: Sad
# Recommended Movie: The Perks of Being a Wallflower (Drama/Romance)
# Faces detected: [[224 137 881 881]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Emotion Detected: Sad
# Recommended Movie: The Shack (Drama)
# Faces detected: [[225 134 900 900]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Emotion Detected: Sad
# Recommended Movie: Schindler's List (History/Drama)
# Faces detected: [[226 157 882 882]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Emotion Detected: Sad
# Recommended Movie: My Sister's Keeper (Drama)
# Faces detected: [[260 234 832 832]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Emotion Detected: Sad
# Recommended Movie: Lion (Drama)
# Faces detected: ()
# Faces detected: ()
# Faces detected: [[279 349 250 250]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Emotion Detected: Surprise
# Recommended Movie: Primal Fear (Thriller/Drama)
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
# Faces detected: ()
